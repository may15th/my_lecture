# %%
#gravity/연습문제_1/ppt

# %%
#4828_min_max/learn
#MY_SOL
T = int(input())


for tc in range(1 ,T+1):
    N,M = map(int, input().split())
    arr = list(map(int, input().split()))
min = arr[0] + arr[1] + arr[2]
max = arr[0] + arr[1] + arr[2]

print(arr)
print(min,max)

for i in range(0, N-M+1):
    ans = arr[i] +arr[i+1] +arr[i+2]
    if ans <= min:
        min = ans
print(min)

for j in range(0, N-M+1):
    ans = arr[j] +arr[j+1] +arr[j+2]
    if ans >= max:
        max = ans
print(max)

answer = max - min
print(f'#{tc} {answer}')

# %%
#4835_sumofintervals/learn

# %%
# 1206_view/HW
# 연빈 SOL
T = int(input())
for tc in range(1, T+1):
    N = int(input())
    arr = list(map(int,input().split()))
    count = 0


    for i in range(2, N-2):
        #2
        highest = 0
        #left
        if arr[i-2] < arr[i-1]:
            highest = arr[i-1]
        else:
            highest = arr[i-2]
        #right
        if highest<arr[i+1]:
            highest = arr[i+1]
        if highest < arr[i+2]:
            highest =arr[i+2]
    
        # cnt에 차이가 작은것 더하기
        if highest < arr[i]:
            count += arr[i] - highest

    print(f'#{tc} {count}')

# T = 10 # testcase 10개

# for tc in range(1, T+1):
#     N = int(input()) # number of buildings
#     buildings = list(map(int, input().split())) # height of buildings
#     cnt = 0

#     # another solv
#     # 양옆 두개 꼭대기 비교해서 제일 작은 차이값이 세대수
#     for i in range(2, N-2): # 2 ~ N-3 (N-1이 마지막)
#         # [i-2] [i-1] [i+1] [i+2]
#         nxt = 0

#         # 4개 중 높은 빌딩 구하기
#         # left
#         if buildings[i-2] < buildings[i-1]:
#             nxt = buildings[i-1]
#         else:
#             nxt = buildings[i-2]
#         # right # 이것도 위랑 똑같이 했을땐 왜 안나왔지?
#         if nxt < buildings[i+1]:
#             nxt = buildings[i+1]
#         if nxt < buildings[i+2]:
#             nxt = buildings[i+2]

#         # cnt에 차이가 작은거 더하기
#         if nxt < buildings[i]:
#             cnt += buildings[i] - nxt
#     print(f'#{tc} {cnt}')


# 현기 형  풀이

for tc in range(1,11):
    N=int(input())
    building = list(map(int, input().split()))

    sum_building = 0

    for i in range(2,N-2):

        max_building = building[i-2]

        if max_building <building[i-1]:
            max_building = building[i-1]
        if max_building <building[i+1]:
            max_building = building[i+1]
        if max_building <building[i+2]:
            max_building = building[i+2]

        if building[i] > max_building:
            sum_building += building[i] - max_building
